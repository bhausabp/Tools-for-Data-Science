# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name is Bhausab Paramanatti and I hope to be a data analyst

# %% [markdown]
# \"_I am interested in data science because it is in hot demand and pays good money_"

# %% [markdown]
# \n

# %%
"1 + 1\".\n"
# Out:
# '1 + 1".\n'

# %% [markdown]
# - item 1
# - item 2
#
# ![duck.jpg](attachment:471d77d7-72f2-4fb6-a269-feb17ff8b6ad.jpg)
#
# https://en.wikipedia.org/wiki/Duck_test
#
# *Strikethrough*
